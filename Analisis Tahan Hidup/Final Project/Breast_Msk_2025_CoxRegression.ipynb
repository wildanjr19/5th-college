# %%
import pandas as pd

# Import file .tsv
df = pd.read_csv('breast_msk_2025_clinical_data.tsv', sep='\t')

# Tampilkan nama kolom
print("Nama kolom:")
print(df.columns.tolist())
# Out:
# Nama kolom:
# ['Study ID', 'Patient ID', 'Sample ID', 'Cancer Type', 'Cancer Type Detailed', 'Ethnicity', 'Fraction Genome Altered', 'Sex', 'Gene Panel', 'Metastatic Site', 'MSI Comment', 'MSI Score', 'MSI Type', 'Mutation Count', 'Oncotree Code', 'Overall Survival (Months)', 'Overall Survival Status', 'Primary Tumor Site', 'Race', 'Sample Class', 'Number of Samples Per Patient', 'Sample coverage', 'Sample Type', 'Somatic Status', 'Tumor Purity']

# %%
# Mengubah nilai di kolom 'Overall Survival Status'
df['Overall Survival Status'] = df['Overall Survival Status'].map({'1:DECEASED': 1, '0:LIVING': 0})

# Tampilkan nilai unik setelah mapping untuk verifikasi
print("Nilai unik di kolom 'Overall Survival Status' setelah mapping:")
print(df['Overall Survival Status'].unique())
# Out:
# Nilai unik di kolom 'Overall Survival Status' setelah mapping:
# [ 1.  0. nan]

# %%
from lifelines import CoxPHFitter
import pandas as pd

# Pilih kolom yang diperlukan
columns_needed = [
    'Overall Survival (Months)',
    'Overall Survival Status',
    'Cancer Type Detailed',
    'Primary Tumor Site',
    'Metastatic Site',
    'MSI Type',
    'Mutation Count',
    'Fraction Genome Altered'
]

# Buat subset data dan drop NaN
data_cox = df[columns_needed].dropna()

# Pastikan tipe data benar
data_cox['Overall Survival (Months)'] = data_cox['Overall Survival (Months)'].astype(float)
data_cox['Overall Survival Status'] = data_cox['Overall Survival Status'].astype(int)

# Encode kolom kategorikal ke dummy variables
categorical_cols = ['Cancer Type Detailed', 'Primary Tumor Site', 'Metastatic Site', 'MSI Type']
data_cox_encoded = pd.get_dummies(data_cox, columns=categorical_cols, drop_first=True)

# Tampilkan info data setelah encoding
print(f"Jumlah sampel setelah drop NaN dan encoding: {len(data_cox_encoded)}")
print("Kolom setelah encoding:")
print(data_cox_encoded.columns.tolist())

# Fit model Cox Proportional Hazards
cph = CoxPHFitter(penalizer=0.1)  # Tambahkan penalizer untuk mengatasi kolinearitas
cph.fit(data_cox_encoded, duration_col='Overall Survival (Months)', event_col='Overall Survival Status')

# Tampilkan summary model
print("\nSummary Model Cox:")
print(cph.summary)

# Uji asumsi proportional hazards
print("\nUji Asumsi Proportional Hazards:")
try:
    results = cph.check_assumptions(data_cox_encoded, p_value_threshold=0.05)
    print(results)
except Exception as e:
    print(f"Error dalam uji asumsi: {e}")
# Out:
# Jumlah sampel setelah drop NaN dan encoding: 1929
# Kolom setelah encoding:
# ['Overall Survival (Months)', 'Overall Survival Status', 'Mutation Count', 'Fraction Genome Altered', 'Cancer Type Detailed_Adenomyoepithelioma of the Breast', 'Cancer Type Detailed_Breast Invasive Cancer, NOS', 'Cancer Type Detailed_Breast Invasive Carcinoma, NOS', 'Cancer Type Detailed_Breast Invasive Carcinosarcoma, NOS', 'Cancer Type Detailed_Breast Invasive Ductal Carcinoma', 'Cancer Type Detailed_Breast Invasive Lobular Carcinoma', 'Cancer Type Detailed_Breast Invasive Mixed Mucinous Carcinoma', 'Cancer Type Detailed_Breast Mixed Ductal and Lobular Carcinoma', 'Cancer Type Detailed_Breast Neoplasm, NOS', 'Cancer Type Detailed_Cancer of Unknown Primary', 'Cancer Type Detailed_Invasive Breast Carcinoma', 'Cancer Type Detailed_Juvenile Secretory Carcinoma of the Breast', 'Cancer Type Detailed_Metaplastic Breast Cancer', 'Cancer Type Detailed_Metaplastic Squamous Cell Carcinoma', 'Primary Tumor Site_Cancer of Unknown Primary', 'Metastatic Site_Abdominal Wall', 'Metastatic Site_Adrenal', 'Metastatic Site_Adrenal Gland', 'Metastatic Site_Ascites Fluid', 'Metastatic Site_Axilla', 'Metastatic Site_Axillary Lypmh Nodes', 'Metastatic Site_Back', 'Metastatic Site_Bladder', 'Metastatic Site_Bone', 'Metastatic Site_Bowel', 'Metastatic Site_Brain', 'Metastatic Site_Brain and Leptomeninges', 'Metastatic Site_Buttock', 'Metastatic Site_CSF', 'Metastatic Site_Cerebellum', 'Metastatic Site_Cervix', 'Metastatic Site_Chest Wall', 'Metastatic Site_Colon', 'Metastatic Site_Contralateral Breast', 'Metastatic Site_Epidural', 'Metastatic Site_Epidural Mass', 'Metastatic Site_Esophagus', 'Metastatic Site_Fallopian Tube', 'Metastatic Site_Femur', 'Metastatic Site_Humerus', 'Metastatic Site_Iliac Bone', 'Metastatic Site_Ipsilateral Breast', 'Metastatic Site_Kidney', 'Metastatic Site_Left Axilla', 'Metastatic Site_Left Frontal Brain', 'Metastatic Site_Liver', 'Metastatic Site_Lung', 'Metastatic Site_Lymph Node', 'Metastatic Site_Lymph node', 'Metastatic Site_Mediastinal Mass', 'Metastatic Site_Mediastinum', 'Metastatic Site_Muscle', 'Metastatic Site_Neck', 'Metastatic Site_Omentum', 'Metastatic Site_Orbit', 'Metastatic Site_Orbit - Right', 'Metastatic Site_Orbital Floor', 'Metastatic Site_Ovary', 'Metastatic Site_Pancreas', 'Metastatic Site_Parasternal Mass', 'Metastatic Site_Pelvis', 'Metastatic Site_Pericardium', 'Metastatic Site_Peritoneal Fluid', 'Metastatic Site_Peritoneum', 'Metastatic Site_Pleura', 'Metastatic Site_Pleural Fluid', 'Metastatic Site_Pterygoid Palatine Tissue', 'Metastatic Site_Rectum', 'Metastatic Site_Retroperitenium', 'Metastatic Site_Retroperitoneum', 'Metastatic Site_Rib', 'Metastatic Site_Right Neck', 'Metastatic Site_Sacral Mass', 'Metastatic Site_Scalp', 'Metastatic Site_Skin', 'Metastatic Site_Soft Tissue', 'Metastatic Site_Soft tissue / lymph node', 'Metastatic Site_Soft tissue, Posterior Left Shoulder', 'Metastatic Site_Spine', 'Metastatic Site_Spine (Bone)', 'Metastatic Site_Spine (bone)', 'Metastatic Site_Spleen', 'Metastatic Site_Sternum', 'Metastatic Site_Stomach', 'Metastatic Site_Tibia', 'Metastatic Site_Trachea', 'Metastatic Site_Transverse Colon', 'Metastatic Site_Unknown', 'Metastatic Site_Upper Back', 'Metastatic Site_Uterus', 'Metastatic Site_Uterus/Cervix', 'Metastatic Site_Vertebrate', 'Metastatic Site_chest wall', 'Metastatic Site_csf', 'Metastatic Site_soft tissue', 'MSI Type_Indeterminate', 'MSI Type_Instable', 'MSI Type_Stable']
#
# Summary Model Cox:
#                                                         coef  exp(coef)  \
# covariate
# Mutation Count                                      0.010181   1.010233
# Fraction Genome Altered                             0.770845   2.161592
# Cancer Type Detailed_Adenomyoepithelioma of the...  1.323701   3.757302
# Cancer Type Detailed_Breast Invasive Cancer, NOS    0.121320   1.128986
# Cancer Type Detailed_Breast Invasive Carcinoma,... -0.154599   0.856759
# ...                                                      ...        ...
# Metastatic Site_csf                                 1.418636   4.131480
# Metastatic Site_soft tissue                         0.784861   2.192102
# MSI Type_Indeterminate                              0.234600   1.264403
# MSI Type_Instable                                  -0.373749   0.688150
# MSI Type_Stable                                    -0.018740   0.981435
#
#                                                     se(coef)  coef lower 95%  \
# covariate
# Mutation Count                                      0.003663        0.003001
# Fraction Genome Altered                             0.144557        0.487518
# Cancer Type Detailed_Adenomyoepithelioma of the...  1.024836       -0.684941
# Cancer Type Detailed_Breast Invasive Cancer, NOS    0.144771       -0.162426
# Cancer Type Detailed_Breast Invasive Carcinoma,...  0.122804       -0.395289
# ...                                                      ...             ...
# Metastatic Site_csf                                 1.026595       -0.593453
# Metastatic Site_soft tissue                         2.293723       -3.710753
# MSI Type_Indeterminate                              0.123799       -0.008041
# MSI Type_Instable                                   0.502150       -1.357944
# MSI Type_Stable                                     0.082203       -0.179854
#
#                                                     coef upper 95%  \
# covariate
# Mutation Count                                            0.017361
# Fraction Genome Altered                                   1.054172
# Cancer Type Detailed_Adenomyoepithelioma of the...        3.332343
# Cancer Type Detailed_Breast Invasive Cancer, NOS          0.405066
# Cancer Type Detailed_Breast Invasive Carcinoma,...        0.086092
# ...                                                            ...
# Metastatic Site_csf                                       3.430724
# Metastatic Site_soft tissue                               5.280475
# MSI Type_Indeterminate                                    0.477241
# MSI Type_Instable                                         0.610446
# MSI Type_Stable                                           0.142375
#
#                                                     exp(coef) lower 95%  \
# covariate
# Mutation Count                                                 1.003005
# Fraction Genome Altered                                        1.628270
# Cancer Type Detailed_Adenomyoepithelioma of the...             0.504120
# Cancer Type Detailed_Breast Invasive Cancer, NOS               0.850079
# Cancer Type Detailed_Breast Invasive Carcinoma,...             0.673485
# ...                                                                 ...
# Metastatic Site_csf                                            0.552417
# Metastatic Site_soft tissue                                    0.024459
# MSI Type_Indeterminate                                         0.991991
# MSI Type_Instable                                              0.257189
# MSI Type_Stable                                                0.835392
#
#                                                     exp(coef) upper 95%  \
# covariate
# Mutation Count                                                 1.017513
# Fraction Genome Altered                                        2.869599
# Cancer Type Detailed_Adenomyoepithelioma of the...            28.003886
# Cancer Type Detailed_Breast Invasive Cancer, NOS               1.499401
# Cancer Type Detailed_Breast Invasive Carcinoma,...             1.089907
# ...                                                                 ...
# Metastatic Site_csf                                           30.899014
# Metastatic Site_soft tissue                                  196.463157
# MSI Type_Indeterminate                                         1.611622
# MSI Type_Instable                                              1.841253
# MSI Type_Stable                                                1.153008
#
#                                                     cmp to         z  \
# covariate
# Mutation Count                                         0.0  2.779075
# Fraction Genome Altered                                0.0  5.332452
# Cancer Type Detailed_Adenomyoepithelioma of the...     0.0  1.291622
# Cancer Type Detailed_Breast Invasive Cancer, NOS       0.0  0.838014
# Cancer Type Detailed_Breast Invasive Carcinoma,...     0.0 -1.258910
# ...                                                    ...       ...
# Metastatic Site_csf                                    0.0  1.381885
# Metastatic Site_soft tissue                            0.0  0.342178
# MSI Type_Indeterminate                                 0.0  1.895013
# MSI Type_Instable                                      0.0 -0.744298
# MSI Type_Stable                                        0.0 -0.227971
#
#                                                                p   -log2(p)
# covariate
# Mutation Count                                      5.451399e-03   7.519158
# Fraction Genome Altered                             9.689529e-08  23.298998
# Cancer Type Detailed_Adenomyoepithelioma of the...  1.964881e-01   2.347486
# Cancer Type Detailed_Breast Invasive Cancer, NOS    4.020231e-01   1.314650
# Cancer Type Detailed_Breast Invasive Carcinoma,...  2.080628e-01   2.264909
# ...                                                          ...        ...
# Metastatic Site_csf                                 1.670070e-01   2.582019
# Metastatic Site_soft tissue                         7.322172e-01   0.449656
# MSI Type_Indeterminate                              5.809065e-02   4.105550
# MSI Type_Instable                                   4.566961e-01   1.130694
# MSI Type_Stable                                     8.196691e-01   0.286886
#
# [100 rows x 11 columns]
#
# Uji Asumsi Proportional Hazards:
# The ``p_value_threshold`` is set at 0.05. Even under the null hypothesis of no violations, some
# covariates will be below the threshold by chance. This is compounded when there are many covariates.
# Similarly, when there are lots of observations, even minor deviances from the proportional hazard
# assumption will be flagged.
#
# With that in mind, it's best to use a combination of statistical tests and visual tests to determine
# the most serious violations. Produce visual plots using ``check_assumptions(..., show_plots=True)``
# and looking for non-constant lines. See link [A] below for a full example.
# <lifelines.StatisticalResult: proportional_hazard_test>
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = <lifelines.CoxPHFitter: fitted with 1929 total observations, 504 right-censored observations>
#          test_name = proportional_hazard_test
#
# ---
#                                                                       test_statistic    p  -log2(p)
# Cancer Type Detailed_Adenomyoepithelioma of the Breast          km              0.56 0.45      1.14
#                                                                 rank            0.59 0.44      1.17
# Cancer Type Detailed_Breast Invasive Cancer, NOS                km              0.00 0.97      0.04
#                                                                 rank            0.00 0.98      0.03
# Cancer Type Detailed_Breast Invasive Carcinoma, NOS             km              1.41 0.24      2.09
#                                                                 rank            1.43 0.23      2.11
# Cancer Type Detailed_Breast Invasive Carcinosarcoma, NOS        km              0.61 0.44      1.20
#                                                                 rank            0.53 0.47      1.10
# Cancer Type Detailed_Breast Invasive Ductal Carcinoma           km              0.16 0.68      0.55
#                                                                 rank            0.17 0.68      0.56
# Cancer Type Detailed_Breast Invasive Lobular Carcinoma          km              0.32 0.57      0.81
#                                                                 rank            0.33 0.56      0.83
# Cancer Type Detailed_Breast Invasive Mixed Mucinous Carcinoma   km              2.10 0.15      2.76
#                                                                 rank            2.11 0.15      2.77
# Cancer Type Detailed_Breast Mixed Ductal and Lobular Carcinoma  km              0.16 0.68      0.55
#                                                                 rank            0.14 0.71      0.50
# Cancer Type Detailed_Breast Neoplasm, NOS                       km              0.01 0.93      0.10
#                                                                 rank            0.01 0.93      0.10
# Cancer Type Detailed_Cancer of Unknown Primary                  km              0.04 0.85      0.24
#                                                                 rank            0.04 0.84      0.25
# Cancer Type Detailed_Invasive Breast Carcinoma                  km              0.24 0.63      0.68
#                                                                 rank            0.25 0.62      0.69
# Cancer Type Detailed_Juvenile Secretory Carcinoma of the Breast km              1.73 0.19      2.40
#                                                                 rank            1.83 0.18      2.50
# Cancer Type Detailed_Metaplastic Breast Cancer                  km              0.69 0.41      1.30
#                                                                 rank            0.72 0.40      1.33
# Cancer Type Detailed_Metaplastic Squamous Cell Carcinoma        km              0.01 0.94      0.09
#                                                                 rank            0.01 0.93      0.10
# Fraction Genome Altered                                         km              0.36 0.55      0.86
#                                                                 rank            0.26 0.61      0.71
# MSI Type_Indeterminate                                          km              0.99 0.32      1.65
#                                                                 rank            0.99 0.32      1.65
# MSI Type_Instable                                               km              1.10 0.29      1.76
#                                                                 rank            0.92 0.34      1.56
# MSI Type_Stable                                                 km              1.50 0.22      2.18
#                                                                 rank            1.49 0.22      2.17
# Metastatic Site_Abdominal Wall                                  km              0.15 0.69      0.53
#                                                                 rank            0.17 0.68      0.56
# Metastatic Site_Adrenal                                         km              0.62 0.43      1.21
#                                                                 rank            0.66 0.42      1.26
# Metastatic Site_Adrenal Gland                                   km              0.00 0.96      0.06
#                                                                 rank            0.00 0.97      0.04
# Metastatic Site_Ascites Fluid                                   km              0.16 0.69      0.53
#                                                                 rank            0.18 0.67      0.57
# Metastatic Site_Axilla                                          km              0.39 0.53      0.91
#                                                                 rank            0.46 0.50      1.01
# Metastatic Site_Axillary Lypmh Nodes                            km              0.10 0.75      0.42
#                                                                 rank            0.10 0.75      0.42
# Metastatic Site_Back                                            km              1.13 0.29      1.79
#                                                                 rank            0.80 0.37      1.43
# Metastatic Site_Bladder                                         km              0.04 0.84      0.25
#                                                                 rank            0.04 0.85      0.24
# Metastatic Site_Bone                                            km              2.47 0.12      3.11
#                                                                 rank            2.34 0.13      2.98
# Metastatic Site_Bowel                                           km              0.37 0.54      0.88
#                                                                 rank            0.38 0.54      0.90
# Metastatic Site_Brain                                           km              1.31 0.25      1.98
#                                                                 rank            1.12 0.29      1.78
# Metastatic Site_Brain and Leptomeninges                         km              1.03 0.31      1.69
#                                                                 rank            1.03 0.31      1.69
# Metastatic Site_Buttock                                         km              0.99 0.32      1.65
#                                                                 rank            0.93 0.34      1.57
# Metastatic Site_CSF                                             km              0.07 0.79      0.35
#                                                                 rank            0.08 0.77      0.37
# Metastatic Site_Cerebellum                                      km              0.07 0.79      0.35
#                                                                 rank            0.07 0.79      0.34
# Metastatic Site_Cervix                                          km              0.11 0.74      0.43
#                                                                 rank            0.12 0.73      0.46
# Metastatic Site_Chest Wall                                      km              6.40 0.01      6.45
#                                                                 rank            6.48 0.01      6.52
# Metastatic Site_Colon                                           km              2.42 0.12      3.06
#                                                                 rank            2.09 0.15      2.75
# Metastatic Site_Contralateral Breast                            km              0.00 0.99      0.02
#                                                                 rank            0.00 0.99      0.02
# Metastatic Site_Epidural                                        km              0.80 0.37      1.43
#                                                                 rank            0.73 0.39      1.35
# Metastatic Site_Epidural Mass                                   km              2.20 0.14      2.86
#                                                                 rank            2.08 0.15      2.74
# Metastatic Site_Esophagus                                       km              0.52 0.47      1.09
#                                                                 rank            0.53 0.47      1.10
# Metastatic Site_Fallopian Tube                                  km              0.08 0.77      0.38
#                                                                 rank            0.08 0.77      0.37
# Metastatic Site_Femur                                           km              0.01 0.94      0.09
#                                                                 rank            0.01 0.93      0.10
# Metastatic Site_Humerus                                         km              0.90 0.34      1.54
#                                                                 rank            0.93 0.34      1.57
# Metastatic Site_Iliac Bone                                      km              1.43 0.23      2.10
#                                                                 rank            1.24 0.27      1.91
# Metastatic Site_Ipsilateral Breast                              km              0.02 0.89      0.17
#                                                                 rank            0.01 0.94      0.09
# Metastatic Site_Kidney                                          km              0.03 0.87      0.21
#                                                                 rank            0.03 0.87      0.21
# Metastatic Site_Left Axilla                                     km              1.10 0.30      1.76
#                                                                 rank            1.11 0.29      1.78
# Metastatic Site_Left Frontal Brain                              km              0.04 0.85      0.24
#                                                                 rank            0.04 0.85      0.24
# Metastatic Site_Liver                                           km              0.14 0.70      0.51
#                                                                 rank            0.15 0.70      0.52
# Metastatic Site_Lung                                            km              1.42 0.23      2.10
#                                                                 rank            1.25 0.26      1.93
# Metastatic Site_Lymph Node                                      km              1.71 0.19      2.39
#                                                                 rank            1.61 0.20      2.29
# Metastatic Site_Lymph node                                      km              0.10 0.75      0.41
#                                                                 rank            0.10 0.76      0.40
# Metastatic Site_Mediastinal Mass                                km              0.39 0.53      0.91
#                                                                 rank            0.42 0.51      0.96
# Metastatic Site_Mediastinum                                     km              3.26 0.07      3.81
#                                                                 rank            3.24 0.07      3.80
# Metastatic Site_Muscle                                          km              0.31 0.58      0.79
#                                                                 rank            0.35 0.56      0.85
# Metastatic Site_Neck                                            km              1.06 0.30      1.72
#                                                                 rank            1.09 0.30      1.76
# Metastatic Site_Omentum                                         km              0.01 0.93      0.10
#                                                                 rank            0.01 0.93      0.11
# Metastatic Site_Orbit                                           km              0.07 0.80      0.33
#                                                                 rank            0.08 0.78      0.36
# Metastatic Site_Orbit - Right                                   km              2.05 0.15      2.71
#                                                                 rank            2.03 0.15      2.69
# Metastatic Site_Orbital Floor                                   km              1.08 0.30      1.74
#                                                                 rank            1.01 0.31      1.67
# Metastatic Site_Ovary                                           km              0.02 0.88      0.19
#                                                                 rank            0.01 0.92      0.12
# Metastatic Site_Pancreas                                        km              0.01 0.93      0.11
#                                                                 rank            0.01 0.92      0.12
# Metastatic Site_Parasternal Mass                                km              0.03 0.87      0.21
#                                                                 rank            0.03 0.86      0.21
# Metastatic Site_Pelvis                                          km              3.28 0.07      3.83
#                                                                 rank            3.16 0.08      3.73
# Metastatic Site_Pericardium                                     km              3.22 0.07      3.78
#                                                                 rank            3.25 0.07      3.81
# Metastatic Site_Peritoneal Fluid                                km              0.13 0.72      0.48
#                                                                 rank            0.14 0.71      0.49
# Metastatic Site_Peritoneum                                      km              0.00 1.00      0.00
#                                                                 rank            0.00 0.99      0.02
# Metastatic Site_Pleura                                          km              0.02 0.90      0.15
#                                                                 rank            0.01 0.92      0.11
# Metastatic Site_Pleural Fluid                                   km              0.01 0.91      0.13
#                                                                 rank            0.01 0.92      0.11
# Metastatic Site_Pterygoid Palatine Tissue                       km              0.05 0.82      0.29
#                                                                 rank            0.05 0.82      0.29
# Metastatic Site_Rectum                                          km              0.02 0.88      0.19
#                                                                 rank            0.02 0.88      0.19
# Metastatic Site_Retroperitenium                                 km              0.90 0.34      1.55
#                                                                 rank            0.87 0.35      1.52
# Metastatic Site_Retroperitoneum                                 km              0.11 0.74      0.44
#                                                                 rank            0.09 0.76      0.40
# Metastatic Site_Rib                                             km              0.18 0.67      0.58
#                                                                 rank            0.17 0.68      0.55
# Metastatic Site_Right Neck                                      km              1.06 0.30      1.72
#                                                                 rank            1.05 0.31      1.71
# Metastatic Site_Sacral Mass                                     km              1.34 0.25      2.02
#                                                                 rank            1.36 0.24      2.04
# Metastatic Site_Scalp                                           km              0.00 0.98      0.02
#                                                                 rank            0.00 0.96      0.05
# Metastatic Site_Skin                                            km              0.30 0.58      0.78
#                                                                 rank            0.23 0.63      0.66
# Metastatic Site_Soft Tissue                                     km              0.71 0.40      1.33
#                                                                 rank            0.69 0.41      1.30
# Metastatic Site_Soft tissue / lymph node                        km              0.05 0.83      0.27
#                                                                 rank            0.05 0.83      0.27
# Metastatic Site_Soft tissue, Posterior Left Shoulder            km              1.06 0.30      1.72
#                                                                 rank            1.03 0.31      1.68
# Metastatic Site_Spine                                           km              1.97 0.16      2.64
#                                                                 rank            2.05 0.15      2.71
# Metastatic Site_Spine (Bone)                                    km              0.20 0.66      0.61
#                                                                 rank            0.17 0.68      0.56
# Metastatic Site_Spine (bone)                                    km              0.44 0.51      0.97
#                                                                 rank            0.48 0.49      1.03
# Metastatic Site_Spleen                                          km              0.57 0.45      1.16
#                                                                 rank            0.62 0.43      1.21
# Metastatic Site_Sternum                                         km              0.00 0.97      0.05
#                                                                 rank            0.00 0.98      0.03
# Metastatic Site_Stomach                                         km              0.01 0.91      0.14
#                                                                 rank            0.00 0.96      0.06
# Metastatic Site_Tibia                                           km              0.79 0.37      1.42
#                                                                 rank            0.84 0.36      1.48
# Metastatic Site_Trachea                                         km              0.13 0.72      0.48
#                                                                 rank            0.13 0.71      0.49
# Metastatic Site_Transverse Colon                                km              0.06 0.80      0.31
#                                                                 rank            0.07 0.79      0.34
# Metastatic Site_Unknown                                         km              0.20 0.66      0.60
#                                                                 rank            0.23 0.63      0.66
# Metastatic Site_Upper Back                                      km              0.26 0.61      0.70
#                                                                 rank            0.26 0.61      0.72
# Metastatic Site_Uterus                                          km              0.23 0.63      0.67
#                                                                 rank            0.32 0.57      0.80
# Metastatic Site_Uterus/Cervix                                   km              1.35 0.24      2.03
#                                                                 rank            1.39 0.24      2.07
# Metastatic Site_Vertebrate                                      km              0.55 0.46      1.13
#                                                                 rank            0.55 0.46      1.13
# Metastatic Site_chest wall                                      km              1.03 0.31      1.69
#                                                                 rank            0.99 0.32      1.65
# Metastatic Site_csf                                             km              0.02 0.89      0.18
#                                                                 rank            0.03 0.87      0.20
# Metastatic Site_soft tissue                                     km              0.01 0.94      0.09
#                                                                 rank            0.01 0.93      0.10
# Mutation Count                                                  km              0.06 0.81      0.31
#                                                                 rank            0.09 0.76      0.40
# Primary Tumor Site_Cancer of Unknown Primary                    km              0.04 0.85      0.24
#                                                                 rank            0.04 0.84      0.25
# 1. Variable 'Metastatic Site_Chest Wall' failed the non-proportional test: p-value is 0.0109.
#
#    Advice: with so few unique values (only 2), you can include `strata=['Metastatic Site_Chest
# Wall', ...]` in the call in `.fit`. See documentation in link [E] below.
#
# ---
# [A]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html
# [B]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Bin-variable-and-stratify-on-it
# [C]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Introduce-time-varying-covariates
# [D]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Modify-the-functional-form
# [E]  https://lifelines.readthedocs.io/en/latest/jupyter_notebooks/Proportional%20hazard%20assumption.html#Stratification
#
# []
